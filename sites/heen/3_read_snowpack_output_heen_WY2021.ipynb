# %% [markdown]
# ### Read SNOWPACK Output at HEEN with HRRR-AK
#
# created by Cassie Lumbrazo\
# last updated: May 2026\
# run location: UAS linux\
# python environment: **xarray**

# %%
# import packages 
# %matplotlib inline

# plotting packages 
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns 

sns.set_theme()
plt.rcParams['figure.figsize'] = [12,6] #overriding size

# data packages 
import pandas as pd
import numpy as np
import xarray as xr
from datetime import datetime

import scipy
import os

# %%
pwd
# Out:
# '/home/cassie/python/repos/snow_modeling_point/sites/heen'

# %% [markdown]
# # Open Data and Model Simulations

# %% [markdown]
# ## Function for Reading SMET Files

# %%
def read_smet(filepath):
    header = {}
    fields = None
    data_start = None

    # Read file and parse header
    with open(filepath, "r") as f:
        lines = f.readlines()

    for i, line in enumerate(lines):
        line = line.strip()

        # Detect fields line
        if line.startswith("fields"):
            fields = line.split("=")[1].strip().split()

        # Detect start of data
        if line == "[DATA]":
            data_start = i + 1
            break

        # Parse header key-value pairs
        if "=" in line and not line.startswith("["):
            key, value = line.split("=", 1)
            header[key.strip()] = value.strip()

    if fields is None:
        raise ValueError("No 'fields' line found in SMET header.")
    if data_start is None:
        raise ValueError("No [DATA] section found.")

    # Read data into DataFrame
    df = pd.read_csv(
        filepath,
        skiprows=data_start,
        delim_whitespace=True,
        names=fields,
        parse_dates=["timestamp"]
    )

    # Set timestamp as index
    df = df.set_index("timestamp")

    # Convert to xarray
    ds = xr.Dataset.from_dataframe(df)

    return ds, header

# %% [markdown]
# ### Open SNOWPACK SMet Output

# %%
ds_snowpack_hrrrak, header = read_smet("/home/cassie/python/models/run_snowpack/sites/heen/output/hrrrak_heen_WY2021_base.smet")
ds_snowpack_hrrrak_scale, header = read_smet("/home/cassie/python/models/run_snowpack/sites/heen/output/hrrrak_scale_heen_WY2021_base.smet")
ds_snowpack_met_hrrrak, header = read_smet("/home/cassie/python/models/run_snowpack/sites/heen/output/met_hrrrak_heen_WY2021_base.smet")
ds_snowpack_met_hrrrak_ffill, header = read_smet("/home/cassie/python/models/run_snowpack/sites/heen/output/met_hrrrak_ffill_heen_WY2021_base.smet")
# Out:
# /tmp/ipykernel_2803172/1183788903.py:33: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(
# /tmp/ipykernel_2803172/1183788903.py:33: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(
# /tmp/ipykernel_2803172/1183788903.py:33: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(
# /tmp/ipykernel_2803172/1183788903.py:33: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(

# %% [markdown]
# ### Open HEEN Observations

# %%
# open observations
file_heen_clean_cut = "/hdd/snow_hydrology/met_station/snotel/heenlatinee/heen_met_2018_2022_cleaned_v1.nc"
heen_obs = xr.open_dataset(file_heen_clean_cut)

# cut the datetime to be from 2021 10 01 to 2025 09 30 to match the snowpack output
heen_obs = heen_obs.sel(time=slice("2020-10-01", "2021-09-30"))
heen_obs
# Out:
# <xarray.Dataset> Size: 698kB
# Dimensions:           (time: 7935)
# Coordinates:
#   * time              (time) datetime64[ns] 63kB 2020-10-01 ... 2021-09-30T23...
# Data variables:
#     swe               (time) float64 63kB ...
#     temp              (time) float64 63kB ...
#     hs                (time) float64 63kB ...
#     rh                (time) float64 63kB ...
#     precip_accum      (time) float64 63kB ...
#     wind              (time) float64 63kB ...
#     wind_dir          (time) float64 63kB ...
#     pressure          (time) float64 63kB ...
#     precip_rate       (time) float64 63kB ...
#     precip_accum_1hr  (time) float64 63kB ...

# %%
# ds_snowpack_hrrrak
# ds_snowpack_hrrrak_scale
# ds_snowpack_met_hrrrak
# ds_snowpack_met_hrrrak_ffill

# %%
ds_snowpack_hrrrak.HS_mod.plot(label = 'SNOWPACK Model with HRRR-AK', linewidth = 3, color='tab:blue')
ds_snowpack_hrrrak_scale.HS_mod.plot(label = 'SNOWPACK Model with HRRR-AK (Only Precip Scaled)', linewidth = 3, color='tab:orange')
ds_snowpack_met_hrrrak.HS_mod.plot(label = 'SNOWPACK Model with Met (Mixed))', linewidth = 3, color='tab:green')
ds_snowpack_met_hrrrak_ffill.HS_mod.plot(label = 'SNOWPACK Model with Met (Mixed) + Ffill', linewidth = 3, color='tab:red')

heen_obs.hs.plot(label = 'Observations', linewidth = 3, color='black')


plt.title('SNOWPACK Simulations at HEEN')
plt.legend()

# plt.ylim([-10, 300])

plt.ylabel('snow depth (cm)')
# Out:
# Text(0, 0.5, 'snow depth (cm)')

# %%
ds_snowpack_hrrrak.HS_mod.plot(label = 'SNOWPACK Model with HRRR-AK', linewidth = 3, color='tab:blue')
ds_snowpack_hrrrak_scale.HS_mod.plot(label = 'SNOWPACK Model with HRRR-AK (Only Precip Scaled)', linewidth = 3, color='tab:orange')
ds_snowpack_met_hrrrak.HS_mod.plot(label = 'SNOWPACK Model with Met (Mixed))', linewidth = 3, color='tab:green')
ds_snowpack_met_hrrrak_ffill.HS_mod.plot(label = 'SNOWPACK Model with Met (Mixed) + Ffill', linewidth = 3, color='tab:red')

heen_obs.hs.plot(label = 'Observations', linewidth = 3, color='black')


plt.title('SNOWPACK Simulations at HEEN')
plt.legend()

# plt.ylim([-10, 300])

plt.ylabel('snow depth (cm)')
# Out:
# Text(0, 0.5, 'snow depth (cm)')

# %%
ds_snowpack_hrrrak.HS_mod.plot(label = 'SNOWPACK Model with HRRR-AK', linewidth = 3, color='tab:blue')
# ds_snowpack_hrrrak_scale.HS_mod.plot(label = 'SNOWPACK Model with HRRR-AK (Only Precip Scaled)', linewidth = 3, color='tab:orange')
ds_snowpack_met_hrrrak.HS_mod.plot(label = 'SNOWPACK Model with Met (Mixed))', linewidth = 3, color='tab:green')
# ds_snowpack_met_hrrrak_ffill.HS_mod.plot(label = 'SNOWPACK Model with Met (Mixed) + Ffill', linewidth = 3, color='tab:red')

heen_obs.hs.plot(label = 'Observations', linewidth = 3, color='black')


plt.title('SNOWPACK Simulations at HEEN')
plt.legend()

# plt.ylim([-10, 300])

plt.ylabel('snow depth (cm)')
# Out:
# Text(0, 0.5, 'snow depth (cm)')

# %% [markdown]
# ### SWE

# %%
ds_snowpack_hrrrak.SWE.plot(label = 'SNOWPACK Model with HRRR-AK', linewidth = 3, color='tab:blue')
ds_snowpack_hrrrak_scale.SWE.plot(label = 'SNOWPACK Model with HRRR-AK (Only Precip Scaled)', linewidth = 3, color='tab:orange')
ds_snowpack_met_hrrrak.SWE.plot(label = 'SNOWPACK Model with Met (Mixed))', linewidth = 3, color='tab:green')
# ds_snowpack_met_hrrrak_ffill.SWE.plot(label = 'SNOWPACK Model with Met (Mixed) + Ffill', linewidth = 3, color='tab:red')

(heen_obs.swe*10).plot(label = 'Observations', linewidth = 3, color='black') # convert SWE to mm 


plt.title('SNOWPACK Simulations at HEEN')
plt.legend()

# plt.ylim([-10, 300])

plt.ylabel('SWE (mm)')
# Out:
# Text(0, 0.5, 'SWE (mm)')

# %%
ds_snowpack_hrrrak.SWE.plot(label = 'SNOWPACK Model with HRRR-AK', linewidth = 3, color='tab:blue')
# ds_snowpack_hrrrak_scale.SWE.plot(label = 'SNOWPACK Model with HRRR-AK (Only Precip Scaled)', linewidth = 3, color='tab:orange')
ds_snowpack_met_hrrrak.SWE.plot(label = 'SNOWPACK Model with Met (Mixed))', linewidth = 3, color='tab:green')
# ds_snowpack_met_hrrrak_ffill.SWE.plot(label = 'SNOWPACK Model with Met (Mixed) + Ffill', linewidth = 3, color='tab:red')

(heen_obs.swe*10).plot(label = 'Observations', linewidth = 3, color='black') # convert SWE to mm 


plt.title('SNOWPACK Simulations at HEEN')
plt.legend()

# plt.ylim([-10, 300])

plt.ylabel('SWE (mm)')
# Out:
# Text(0, 0.5, 'SWE (mm)')
